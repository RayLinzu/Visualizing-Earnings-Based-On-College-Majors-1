# %% [markdown]
# <a href="https://colab.research.google.com/github/RayLinzu/Visualizing-Earnings-Based-On-College-Majors-1/blob/master/Guided_Project_Visualizing_The_Gender_Gap_In_College_Degrees.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt

women_degrees = pd.read_csv('percent-bachelors-degrees-women-usa.csv')
cb_dark_blue = (0/255,107/255,164/255)
cb_orange = (255/255, 128/255, 14/255)
stem_cats = ['Engineering', 'Computer Science', 'Psychology', 'Biology', 'Physical Sciences', 'Math and Statistics']

fig = plt.figure(figsize=(18, 3))

for sp in range(0,6):
    ax = fig.add_subplot(1,6,sp+1)
    ax.plot(women_degrees['Year'], women_degrees[stem_cats[sp]], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[stem_cats[sp]], c=cb_orange, label='Men', linewidth=3)
    ax.spines["right"].set_visible(False)    
    ax.spines["left"].set_visible(False)
    ax.spines["top"].set_visible(False)    
    ax.spines["bottom"].set_visible(False)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.set_title(stem_cats[sp])
    ax.tick_params(bottom="off", top="off", left="off", right="off")
    
    if sp == 0:
        ax.text(2005, 87, 'Men')
        ax.text(2002, 8, 'Women')
    elif sp == 5:
        ax.text(2005, 62, 'Men')
        ax.text(2001, 35, 'Women')
plt.show()

# %%
stem_cats = ['Psychology', 'Biology', 'Math and Statistics', 'Physical Sciences', 'Computer Science', 'Engineering', 'Computer Science']
lib_arts_cats = ['Foreign Languages', 'English', 'Communications and Journalism', 'Art and Performance', 'Social Sciences and History']
other_cats = ['Health Professions', 'Public Administration', 'Education', 'Agriculture','Business', 'Architecture']

# %%
fig = plt.figure(figsize=(16, 16))

for sp in range(0,18,3):
    index = int(sp/3)
    ax = fig.add_subplot(6,3,1+sp)
    ax.plot(women_degrees['Year'], women_degrees[stem_cats[index]], label='Women',linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[stem_cats[index]], label='Men', linewidth=3)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0, 100)
    ax.set_title(stem_cats[index])
    for key,spine in ax.spines.items():
        spine.set_visible(False)
    ax.tick_params(bottom='off', top='off', left='off', right='off')
    
    if index == 0:
        ax.text(2005, 87, 'Men')
        ax.text(2002, 8, 'Women')
    elif index == 5:
        ax.text(2005, 62, 'Men')
        ax.text(2001, 35, 'Women')
for sp in range(1,16,3):
    index = int((sp-1)/3)
    ax = fig.add_subplot(6,3,1+sp)
    ax.plot(women_degrees['Year'], women_degrees[lib_arts_cats[index]], label='Women',linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[lib_arts_cats[index]], label='Men', linewidth=3)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0, 100)
    ax.set_title(lib_arts_cats[index])
    for key,spine in ax.spines.items():
        spine.set_visible(False)
    ax.tick_params(bottom='off', top='off', left='off', right='off')
    
    if index == 0:
        ax.text(2005, 87, 'Men')
        ax.text(2002, 8, 'Women')
    
for sp in range(2,20,3):
    index = int((sp-2)/3)
    ax = fig.add_subplot(6,3,1+sp)
    ax.plot(women_degrees['Year'], women_degrees[other_cats[index]], label='Women',linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[other_cats[index]], label='Men', linewidth=3)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0, 100)
    ax.set_title(other_cats[index])
    for key,spine in ax.spines.items():
        spine.set_visible(False)
    ax.tick_params(bottom='off', top='off', left='off', right='off')
    
    if index == 0:
        ax.text(2005, 87, 'Men')
        ax.text(2002, 8, 'Women')
    elif index == 5:
        ax.text(2005, 62, 'Men')
        ax.text(2001, 35, 'Women')
plt.show()

# %%
#Disable the x-axis labels for all line charts except the bottommost line charts in each column.
fig = plt.figure(figsize=(16, 16))

for sp in range(0,18,3):
    index = int(sp/3)
    ax = fig.add_subplot(6,3,1+sp)
    ax.plot(women_degrees['Year'], women_degrees[stem_cats[index]], label='Women',linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[stem_cats[index]], label='Men', linewidth=3)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0, 100)
    ax.set_title(stem_cats[index])
    for key,spine in ax.spines.items():
        spine.set_visible(False)
    ax.tick_params(bottom='off', top='off', left='off', right='off', labelbottom='off')
    
    if index == 0:
        ax.text(2005, 87, 'Men')
        ax.text(2002, 8, 'Women')
    elif index == 5:
        ax.text(2005, 62, 'Men')
        ax.text(2001, 35, 'Women')
        ax.tick_params(labelbottom='on')
for sp in range(1,16,3):
    index = int((sp-1)/3)
    ax = fig.add_subplot(6,3,1+sp)
    ax.plot(women_degrees['Year'], women_degrees[lib_arts_cats[index]], label='Women',linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[lib_arts_cats[index]], label='Men', linewidth=3)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0, 100)
    ax.set_title(lib_arts_cats[index])
    for key,spine in ax.spines.items():
        spine.set_visible(False)
    ax.tick_params(bottom='off', top='off', left='off', right='off',labelbottom='off')
    
    if index == 0:
        ax.text(2005, 87, 'Men')
        ax.text(2002, 8, 'Women')
    elif index == 4:
        ax.tick_params(labelbottom='on')
        
    
for sp in range(2,20,3):
    index = int((sp-2)/3)
    ax = fig.add_subplot(6,3,1+sp)
    ax.plot(women_degrees['Year'], women_degrees[other_cats[index]], label='Women',linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[other_cats[index]], label='Men', linewidth=3)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0, 100)
    ax.set_title(other_cats[index])
    for key,spine in ax.spines.items():
        spine.set_visible(False)
    ax.tick_params(bottom='off', top='off', left='off', right='off',labelbottom='off')
    
    if index == 0:
        ax.text(2005, 87, 'Men')
        ax.text(2002, 8, 'Women')
    elif index == 5:
        ax.text(2005, 62, 'Men')
        ax.text(2001, 35, 'Women')
        ax.tick_params(labelbottom='on')
plt.show()

# %%
#Enable just the y-axis labels at 0 and 100
fig = plt.figure(figsize=(16, 16))

for sp in range(0,18,3):
    index = int(sp/3)
    ax = fig.add_subplot(6,3,1+sp)
    ax.plot(women_degrees['Year'], women_degrees[stem_cats[index]], label='Women',linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[stem_cats[index]], label='Men', linewidth=3)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0, 100)
    ax.set_title(stem_cats[index])
    ax.set_yticks([0,100])
    for key,spine in ax.spines.items():
        spine.set_visible(False)
    ax.tick_params(bottom='off', top='off', left='off', right='off', labelbottom='off')
    
    if index == 0:
        ax.text(2005, 87, 'Men')
        ax.text(2002, 8, 'Women')
    elif index == 5:
        ax.text(2005, 62, 'Men')
        ax.text(2001, 35, 'Women')
        ax.tick_params(labelbottom='on')
for sp in range(1,16,3):
    index = int((sp-1)/3)
    ax = fig.add_subplot(6,3,1+sp)
    ax.plot(women_degrees['Year'], women_degrees[lib_arts_cats[index]], label='Women',linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[lib_arts_cats[index]], label='Men', linewidth=3)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0, 100)
    ax.set_title(lib_arts_cats[index])
    ax.set_yticks([0,100])
    for key,spine in ax.spines.items():
        spine.set_visible(False)
    ax.tick_params(bottom='off', top='off', left='off', right='off',labelbottom='off')
    
    if index == 0:
        ax.text(2005, 87, 'Men')
        ax.text(2002, 8, 'Women')
    elif index == 4:
        ax.tick_params(labelbottom='on')
        
    
for sp in range(2,20,3):
    index = int((sp-2)/3)
    ax = fig.add_subplot(6,3,1+sp)
    ax.plot(women_degrees['Year'], women_degrees[other_cats[index]], label='Women',linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[other_cats[index]], label='Men', linewidth=3)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0, 100)
    ax.set_title(other_cats[index])
    ax.set_yticks([0,100])
    for key,spine in ax.spines.items():
        spine.set_visible(False)
    ax.tick_params(bottom='off', top='off', left='off', right='off',labelbottom='off')
    
    if index == 0:
        ax.text(2005, 87, 'Men')
        ax.text(2002, 8, 'Women')
    elif index == 5:
        ax.text(2005, 62, 'Men')
        ax.text(2001, 35, 'Women')
        ax.tick_params(labelbottom='on')
plt.show()

# %%
#Generate a horizontal line with the following properties:
#Starts at the y-axis position 50
#Set to the third color (light gray) in the Color Blind 10 palette
#Has a transparency of 0.3
fig = plt.figure(figsize=(16, 16))

for sp in range(0,18,3):
    index = int(sp/3)
    ax = fig.add_subplot(6,3,1+sp)
    ax.plot(women_degrees['Year'], women_degrees[stem_cats[index]], label='Women',linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[stem_cats[index]], label='Men', linewidth=3)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0, 100)
    ax.set_title(stem_cats[index])
    ax.set_yticks([0,100])
    ax.axhline(50, c=(171/255, 171/255, 171/255), alpha=0.3)
    for key,spine in ax.spines.items():
        spine.set_visible(False)
    ax.tick_params(bottom='off', top='off', left='off', right='off', labelbottom='off')
    
    if index == 0:
        ax.text(2005, 87, 'Men')
        ax.text(2002, 8, 'Women')
    elif index == 5:
        ax.text(2005, 62, 'Men')
        ax.text(2001, 35, 'Women')
        ax.tick_params(labelbottom='on')
for sp in range(1,16,3):
    index = int((sp-1)/3)
    ax = fig.add_subplot(6,3,1+sp)
    ax.plot(women_degrees['Year'], women_degrees[lib_arts_cats[index]], label='Women',linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[lib_arts_cats[index]], label='Men', linewidth=3)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0, 100)
    ax.set_title(lib_arts_cats[index])
    ax.set_yticks([0,100])
    ax.axhline(50, c=(171/255, 171/255, 171/255), alpha=0.3)
    for key,spine in ax.spines.items():
        spine.set_visible(False)
    ax.tick_params(bottom='off', top='off', left='off', right='off',labelbottom='off')
    
    if index == 0:
        ax.text(2005, 87, 'Men')
        ax.text(2002, 8, 'Women')
    elif index == 4:
        ax.tick_params(labelbottom='on')
        
    
for sp in range(2,20,3):
    index = int((sp-2)/3)
    ax = fig.add_subplot(6,3,1+sp)
    ax.plot(women_degrees['Year'], women_degrees[other_cats[index]], label='Women',linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[other_cats[index]], label='Men', linewidth=3)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0, 100)
    ax.set_title(other_cats[index])
    ax.set_yticks([0,100])
    ax.axhline(50, c=(171/255, 171/255, 171/255), alpha=0.3)
    for key,spine in ax.spines.items():
        spine.set_visible(False)
    ax.tick_params(bottom='off', top='off', left='off', right='off',labelbottom='off')
    
    if index == 0:
        ax.text(2005, 87, 'Men')
        ax.text(2002, 8, 'Women')
    elif index == 5:
        ax.text(2005, 62, 'Men')
        ax.text(2001, 35, 'Women')
        ax.tick_params(labelbottom='on')
plt.show()
